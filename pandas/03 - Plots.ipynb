# %%
import pandas as pd


def get_csv_df():
    return pd.read_csv('titanic.csv', index_col="PassengerId")

# %% [markdown]
# ## Plotting
#
# Plots use **matplotlib** behind the scenes and plt **numerical columns**.

# %%
get_csv_df().plot()
# Out:
# <AxesSubplot: xlabel='PassengerId'>

# %%
get_csv_df()['Age'].plot()
# Out:
# <AxesSubplot: xlabel='PassengerId'>

# %% [markdown]
# ## Other Plots
#
# There are other plots like **scatter()**, **hist()**, etc. available as methods of Series and DataFrame.
