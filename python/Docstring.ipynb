# %%
"""
Module-level summary or description.

Longer module-level description if needed.
This may span multiple lines.
"""

def example_function(arg1, arg2):
    """Summarize the purpose of the function in one line.

    Longer description of the function's purpose and functionality.
    This may span multiple lines.

    Args:
        arg1 (int): Description of arg1.
        arg2 (str): Description of arg2.

    Returns:
        bool: Description of the return value.

    Raises:
        ValueError: If arg1 is negative.
        TypeError: If arg2 is not a string.
    """
    if arg1 < 0:
        raise ValueError("arg1 cannot be negative.")
    if not isinstance(arg2, str):
        raise TypeError("arg2 must be a string.")

    # Function body here
    return True


class ExampleClass:
    """Summarize the purpose of the class in one line.

    Longer description of the class and its functionality.
    This may span multiple lines.

    Attributes:
        attr1 (int): Description of attr1.
        attr2 (str): Description of attr2.
    """

    def __init__(self, attr1, attr2):
        """Initialize the ExampleClass object.

        Args:
            attr1 (int): Description of attr1.
            attr2 (str): Description of attr2.
        """
        self.attr1 = attr1
        self.attr2 = attr2

    def example_method(self, arg):
        """Summarize the purpose of the method in one line.

        Longer description of the method's purpose and functionality.
        This may span multiple lines.

        Args:
            arg (float): Description of arg.

        Returns:
            bool: Description of the return value.

        Raises:
            ValueError: If arg is negative.
        """
        if arg < 0:
            raise ValueError("arg cannot be negative.")

        # Method body here
        return True

    def example_method2(self):
        """This is an example of a one-liner docstring."""

CONSTANT_VARIABLE = 42
"""Description of the constant variable.

This is a constant value that should not be modified.
"""

pass # suppress unnecessary output in jupyter
